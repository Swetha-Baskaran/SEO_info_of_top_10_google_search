# %% [markdown]
# # ICT MINI PROJECT

# %% [markdown]
# ## SEO - Search Engine Optimization

# %% [markdown]
# ## Module 1 : Scraping Google Search Results

# %%
pip install requests_html

# %%
pip install bs4

# %% [markdown]
# ### Importing required modules for the project

# %%
import requests
from bs4 import BeautifulSoup
import urllib

import json

import pandas

# %% [markdown]
# ### Main code : Implemention of the application

# %%
def search_google():
    print("Search Google : ")
    search_query = input()
    
    query = urllib.parse.quote_plus(search_query)

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}
    url = 'https://www.google.com/search?q={query}'.format(query=query)
    html = requests.get(url, headers=headers)

    soup = BeautifulSoup(html.text, 'html.parser')

    allData = soup.find_all("div", {"class": "g"})

    results = parse_data(allData)
    
    seo_info_hold = []
    err_links = []
    for i in results:
        try:
            value = extract_info(i["link"])
            seo_info_hold.append(value)
        except:
            err_links.append(i["link"])
    
    print("Scraped SEO results : \n")
    display_results(seo_info_hold)
    
    if(len(err_links) > 0):
        print("\nCan't able to scrape these links : \n")
        display_results(err_links)
        
    store_results(seo_info_hold)

# %% [markdown]
# ### Retrive top 10 link of the Google Search based on the given query string

# %%
def parse_data(allData):
    g = 0
    Data = []
    l = {}
    for i in range(0, len(allData)):
        link = allData[i].find('a').get('href')

        if (link is not None):
            if (link.find('https') != -1 and link.find('http') == 0 and link.find('aclk') == -1):
                g = g+1
                l["link"] = link
                try:
                    l["title"] = allData[i].find('h3').text
                except:
                    l["title"] = None
                
                
                Data.append(l)
                
                l = {}

            else:
                continue

        else:
            continue
    return Data

# %% [markdown]
# ### Display the given data in a formatted way

# %%
def display_results(json_data):
    print(json.dumps(json_data, indent = 2))

# %% [markdown]
# ## Module 2 : Scraping each URL to extract SEO information

# %% [markdown]
# ### Scraping SEO information for the links scraped from Google Search

# %%
def extract_info(URL):
    seo_info = {}
    html = requests.get(URL)
    soup = BeautifulSoup(html.text, 'html.parser')
    
    seo_info["link"] = URL
    try:
        seo_info["metatitle"] = (soup.find('title')).get_text()
    except:
        seo_info["metatitle"] = None
    try:
        seo_info["metadescription"] = soup.find('meta',attrs={'name':'description'})["content"]
    except:
        seo_info["metadescription"] = None
    try:
        seo_info["robots directives"] = soup.find('meta',attrs={'name':'robots'})["content"].split(",")
    except:
        seo_info["robots directives"] = None
    try:
        seo_info["viewport"] = soup.find('meta',attrs={'name':'viewport'})["content"]
    except:
        seo_info["viewport"] = None
    try:
        seo_info["charset"] = soup.find('meta',attrs={'charset':True})["charset"]
    except:
        seo_info["charset"] = None
    try:
        seo_info["html language"] = soup.find('html')["lang"]
    except:
        seo_info["html language"] = None
    
    try:
        seo_info["canonical"] = soup.find('link',attrs={'rel':'canonical'})["href"]
    except:
        seo_info["canonical"] = None
    try:
        seo_info["list hreflangs"] = [[a['href'], a["hreflang"]] for a in soup.find_all('link', href=True, hreflang=True)]
    except:
        seo_info["list hreflangs"] = None
    try:
        seo_info["mobile alternate"] = soup.find('link',attrs={'media':'only screen and (max-width: 640px)'})["href"]
    except:
        seo_info["mobile alternate"] = None
    
    return seo_info

# %% [markdown]
# #### Output :

# %%
extract_info("https://www.candy.com")
# Out:
# {'link': 'https://www.candy.com',
#  'metatitle': 'Home - Candy',
#  'metadescription': 'Fandom, reimagined. Only at Candy.com',
#  'robots directives': ['index', 'follow'],
#  'viewport': 'initial-scale=1.0, width=device-width',
#  'charset': 'utf-8',
#  'html language': 'en',
#  'canonical': None,
#  'list hreflangs': [],
#  'mobile alternate': None}

# %% [markdown]
# ## Module 3 : Tabulating the results

# %%
def store_results(data):

    df = pandas.DataFrame(data)

    try:
        print("\nEnter a file name to save your data : ")
        file_name = input()
        writer = pandas.ExcelWriter(file_name)
        df.to_excel(writer, encoding='utf8', index=False)
        writer.save()
        print("Your data successfully saved in " + file_name)
    except:
        print("Error : Can't able to save data to excel file.")

# %%
search_google()
# Out:
# Search Google :
# information technology
# Scraped SEO results :
#
# [
#   {
#     "link": "https://en.wikipedia.org/wiki/Information_technology",
#     "metatitle": "Information technology - Wikipedia",
#     "metadescription": null,
#     "robots directives": [
#       "max-image-preview:standard"
#     ],
#     "viewport": "width=1000",
#     "charset": "UTF-8",
#     "html language": "en",
#     "canonical": "https://en.wikipedia.org/wiki/Information_technology",
#     "list hreflangs": [],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://www.techtarget.com/searchdatacenter/definition/IT",
#     "metatitle": "What is Information Technology? Definition and Examples",
#     "metadescription": "Learn what information technology is, the role of software and hardware, the difference between IT and computer science, IT job functions and careers.",
#     "robots directives": [
#       "noodp"
#     ],
#     "viewport": "width=device-width,initial-scale=1",
#     "charset": "utf-8",
#     "html language": "en",
#     "canonical": "https://www.techtarget.com/searchdatacenter/definition/IT",
#     "list hreflangs": [],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://www.nist.gov/information-technology",
#     "metatitle": "Information Technology | NIST",
#     "metadescription": "NIST advances the state-of-the-art in IT in such applications as cybersecurity and biometrics.",
#     "robots directives": null,
#     "viewport": "width=device-width, initial-scale=1.0",
#     "charset": "utf-8",
#     "html language": "en",
#     "canonical": "https://www.nist.gov/information-technology",
#     "list hreflangs": [],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://www.comptia.org/content/articles/what-is-information-technology",
#     "metatitle": "\r\n\tWhat is Information Technology | Info on IT Careers and Certs | CompTIA\r\n",
#     "metadescription": "Learn what is information technology. Understand the definition as well as the many different types of careers paths available from CompTIA, the voice of information technology.",
#     "robots directives": null,
#     "viewport": "width=device-width, initial-scale=1, maximum-scale=1.0, minimum-scale=1.0",
#     "charset": "utf-8",
#     "html language": "en",
#     "canonical": "https://www.comptia.org/content/articles/what-is-information-technology",
#     "list hreflangs": [
#       [
#         "/content/articles/what-is-information-technology",
#         "en"
#       ],
#       [
#         "/content/articles/what-is-information-technology",
#         "x-default"
#       ]
#     ],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://www.rasmussen.edu/degrees/technology/blog/what-is-information-technology/",
#     "metatitle": "What Is Information Technology? A Beginner\u2019s Guide to the World of IT  | Rasmussen University",
#     "metadescription": "If you\u2019re looking to get a better handle on what information technology is and the many facets of this field, then you\u2019ve come to the right place. We did the digging for you and spoke with IT industry pros to create this helpful beginner\u2019s guide to the field.",
#     "robots directives": null,
#     "viewport": "width=device-width, initial-scale=1",
#     "charset": "utf-8",
#     "html language": "en",
#     "canonical": "https://www.rasmussen.edu/degrees/technology/blog/what-is-information-technology/",
#     "list hreflangs": [],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://www.coursera.org/browse/information-technology",
#     "metatitle": "Best Information Technology Courses Online [2022] | Coursera",
#     "metadescription": "Advance your career in Information Technology with Coursera. We partner with top universities and companies to offer Information Technology courses, certificates and degrees to help you achieve your career goals.",
#     "robots directives": null,
#     "viewport": "width=device-width, initial-scale=1",
#     "charset": "utf-8",
#     "html language": "en",
#     "canonical": "https://www.coursera.org/browse/information-technology",
#     "list hreflangs": [
#       [
#         "https://www.coursera.org/browse/information-technology",
#         "x-default"
#       ],
#       [
#         "https://de.coursera.org/browse/information-technology",
#         "de"
#       ],
#       [
#         "https://es.coursera.org/browse/information-technology",
#         "es"
#       ],
#       [
#         "https://fr.coursera.org/browse/information-technology",
#         "fr"
#       ],
#       [
#         "https://gb.coursera.org/browse/information-technology",
#         "en-gb"
#       ],
#       [
#         "https://in.coursera.org/browse/information-technology",
#         "en-in"
#       ],
#       [
#         "https://mx.coursera.org/browse/information-technology",
#         "es-mx"
#       ],
#       [
#         "https://pt.coursera.org/browse/information-technology",
#         "pt-br"
#       ],
#       [
#         "https://pt.coursera.org/browse/information-technology",
#         "pt"
#       ],
#       [
#         "https://ru.coursera.org/browse/information-technology",
#         "ru"
#       ],
#       [
#         "https://jp.coursera.org/browse/information-technology",
#         "ja-jp"
#       ],
#       [
#         "https://tw.coursera.org/browse/information-technology",
#         "zh-tw"
#       ],
#       [
#         "https://cn.coursera.org/browse/information-technology",
#         "zh-cn"
#       ],
#       [
#         "https://kr.coursera.org/browse/information-technology",
#         "ko-kr"
#       ],
#       [
#         "https://www.coursera.org/browse/information-technology",
#         "en"
#       ]
#     ],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://emeritus.org/in/learn/what-is-information-technology/",
#     "metatitle": "What is Information Technology? Know About the IT World | Emeritus India",
#     "metadescription": "Information technology or IT covers every task a computer is used for. Here are IT certificate courses that will offer aspirants competitive",
#     "robots directives": [
#       "index",
#       " follow",
#       " max-image-preview:large",
#       " max-snippet:-1",
#       " max-video-preview:-1"
#     ],
#     "viewport": "width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover",
#     "charset": "UTF-8",
#     "html language": "en-US",
#     "canonical": "https://emeritus.org/in/learn/what-is-information-technology/",
#     "list hreflangs": [],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://www.meity.gov.in/",
#     "metatitle": "Ministry of Electronics and Information Technology, Government of India | Home Page",
#     "metadescription": "To promote e-Governance for empowering citizens, promoting the inclusive and\u00a0sustainable growth of the Electronics, IT and ITeS industries, enhancing India\u2019s role in Internet Governance,\u00a0enhancing efficiency through digital services.",
#     "robots directives": null,
#     "viewport": "width=device-width",
#     "charset": "utf-8",
#     "html language": "en",
#     "canonical": "https://www.meity.gov.in/",
#     "list hreflangs": [],
#     "mobile alternate": null
#   },
#   {
#     "link": "https://marketbusinessnews.com/financial-glossary/information-technology/",
#     "metatitle": "What is information technology or IT? Definition and examples",
#     "metadescription": "Information technology or IT refers to the development, maintenance, and use of computers, their software, systems, and networks.",
#     "robots directives": [
#       "index",
#       " follow",
#       " max-image-preview:large",
#       " max-snippet:-1",
#       " max-video-preview:-1"
#     ],
#     "viewport": "width=device-width, initial-scale=1.0",
#     "charset": "UTF-8",
#     "html language": "en-US",
#     "canonical": "https://marketbusinessnews.com/financial-glossary/information-technology/",
#     "list hreflangs": [],
#     "mobile alternate": null
#   }
# ]
#
# Enter a file name to save your data :
# IT.xlsx
# Your data successfully saved in IT.xlsx
